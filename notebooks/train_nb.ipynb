# %%
import pandas as pd

# %%
df = pd.read_csv('../data/manufacturing_defect_dataset.csv')
df
# Out:
#       ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# 0                  202    13175.403783        86.648534              1
# 1                  535    19770.046093        86.310664              4
# 2                  960    19060.820997        82.132472              0
# 3                  370     5647.606037        87.335966              5
# 4                  206     7472.222236        81.989893              3
# ...                ...             ...              ...            ...
# 3235               762    11325.689263        89.252385              2
# 3236               335     5598.837988        95.701437              4
# 3237               835    11736.177712        96.431554              5
# 3238               302    13664.196210        91.089782              1
# 3239               355    13563.605806        83.595956              2
#
#       DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# ...

# %%
df['DefectStatus']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3235    0
# 3236    0
# 3237    1
# 3238    0
# 3239    0
# Name: DefectStatus, Length: 3240, dtype: int64

# %%
df['DefectStatus'].value_counts()
# Out:
# DefectStatus
# 1    2723
# 0     517
# Name: count, dtype: int64

# %% [markdown]
# ### TRAIN

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
df['DefectStatus']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3235    0
# 3236    0
# 3237    1
# 3238    0
# 3239    0
# Name: DefectStatus, Length: 3240, dtype: int64

# %%
df.drop('DefectStatus', axis=1)
# Out:
#       ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# 0                  202    13175.403783        86.648534              1
# 1                  535    19770.046093        86.310664              4
# 2                  960    19060.820997        82.132472              0
# 3                  370     5647.606037        87.335966              5
# 4                  206     7472.222236        81.989893              3
# ...                ...             ...              ...            ...
# 3235               762    11325.689263        89.252385              2
# 3236               335     5598.837988        95.701437              4
# 3237               835    11736.177712        96.431554              5
# 3238               302    13664.196210        91.089782              1
# 3239               355    13563.605806        83.595956              2
#
#       DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# ...

# %%
X = df.drop('DefectStatus', axis=1) 
y = df['DefectStatus']

# %%
selector = SelectKBest(score_func=f_regression, k=5)
X_new = selector.fit_transform(X, y)

# %%
selected_features = X.columns[selector.get_support(indices=True)]
print("Selected features:", selected_features)
# Out:
# Selected features: Index(['ProductionVolume', 'DefectRate', 'QualityScore', 'MaintenanceHours',
#        'StockoutRate'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
class_predictions = [1 if pred > 0.5 else 0 for pred in predictions]

accuracy = accuracy_score(y_test, class_predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8626543209876543

# %%
df[['ProductionVolume', 'DefectRate', 'QualityScore', 'MaintenanceHours',
       'StockoutRate']]
# Out:
#       ProductionVolume  DefectRate  QualityScore  MaintenanceHours  \
# 0                  202    3.121492     63.463494                 9
# 1                  535    0.819531     83.697818                20
# 2                  960    4.514504     90.350550                 1
# 3                  370    0.638524     67.628690                 8
# 4                  206    3.867784     82.728334                 9
# ...                ...         ...           ...               ...
# 3235               762    2.667570     87.141681                16
# 3236               335    0.751272     95.562997                11
# 3237               835    4.899756     77.973442                 0
# 3238               302    4.057665     95.755591                 6
# 3239               355    2.705502     94.630965                13
#
#       StockoutRate
# 0         0.081322
# 1         0.038486
# 2         0.002887
# 3         0.055331
# 4         0.068047
# ...            ...
# ...

# %%
print(max(df['ProductionVolume']))
print(max(df['DefectRate']))
print(max(df['QualityScore']))
print(max(df['MaintenanceHours']))
print(max(df['StockoutRate']))
# Out:
# 999
# 4.998529423589416
# 99.99699307332706
# 23
# 0.0999973867646256

# %%
# from cryptography.fernet import Fernet
# key = Fernet.generate_key()
# print(key.decode())
# Out:
# yoyu1HdmVSRjXB88UNjlmaAehvRTGWUyJtPoaSH-wls=
